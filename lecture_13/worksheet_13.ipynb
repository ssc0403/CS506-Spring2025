# %% [markdown]
# # Worksheet
#
# [FORM](https://forms.gle/VsMXb6bE83RP95R37)

# %% [markdown]
# ### Model Evaluation
#
# Write a function to generate the confusion matrix for a list of actual classes and a list of predicted classes

# %%
import numpy as np

actual_class = ["Yes", "No", "No", "Yes", "No", "No", "Yes", "No", "No", "No"]
predicted_class = ["Yes", "No", "Yes", "No", "No", "No", "Yes", "Yes", "Yes", "No"]

def confusion_matrix(actual, predicted):
    tp = sum([1 for i in range(len(actual_class)) if (actual_class[i] == predicted_class[i]) and actual_class[i] == "Yes"])
    fn = sum([1 for i in range(len(actual_class)) if (actual_class[i] != predicted_class[i]) and actual_class[i] == "Yes"])
    fp = sum([1 for i in range(len(actual_class)) if (actual_class[i] != predicted_class[i]) and actual_class[i] == "No"])
    tn = sum([1 for i in range(len(actual_class)) if (actual_class[i] == predicted_class[i]) and actual_class[i] == "No"])

    np_matrix = np.array([[tp, fn], [fp, tn]])
    mat = [tp, fn, fp, tn]

    return mat

print(confusion_matrix(actual_class, predicted_class))
# Out:
# [2, 1, 3, 4]

# %% [markdown]
# Assume you have the following Cost Matrix:
#
# |            | predicted = Y | predicted = N |
# |------------|---------------|---------------|
# | actual = Y |       -1      |       5       |
# | actual = N |        10     |       0       |
#
# What is the cost of the above classification?

# %% [markdown]
# The cost of the above classification is (-2 + 5 + 30 + 0) = 33
